# %%
import json, re, random
import pandas as pd
import numpy as np

# %%
data = pd.read_json("my_export.json")
data
# Out:
#                                                     Note  \
# 0      **1. Subjective:** **Chief Complaint (CC):** -...
# 1      **1. Subjective:** - **Chief Complaint (CC):**...
# 2      **1. Subjective:****Chief Complaint (CC):**Sev...
# 3      **1. Subjective:****Chief Complaint (CC):** Mo...
# 4      **1. Subjective:****Chief Complaint (CC):** Mo...
# ...                                                  ...
# 10232  **1. Subjective:****Chief Complaint (CC):** Ni...
# 10233  **1. Subjective:** **Chief Complaint (CC):**Di...
# 10234  **1. Subjective:****Chief Complaint (CC):**Dif...
# 10235  **1. Subjective:****Chief Complaint (CC):** Se...
# 10236  **1. Subjective:****Chief Complaint (CC):**The...
#
#                                                 Dialogue   ICD10  \
# 0      [doctor]: Hello! It’s good to see you today. H...  M25562
# 1      [doctor] Hi there, how are you today?[patient]...  M25562
# 2      [doctor] Good morning, how are you doing today...  M25562
# 3      [doctor] Good morning! How are you feeling tod...  M25562
# 4      [doctor]: Hello Mr. Doe, how are you doing tod...  M25562
# ...                                                  ...     ...
# 10232  [doctor]: Good morning! How are you doing toda...   N6452
# 10233  [doctor]: Good morning. How are you doing toda...   B3781
# 10234  [doctor]: Hi Mr. Harris, how are you doing tod...   B3781
# 10235  [doctor]: Good morning, Ms. Lee. How are you d...   B3781
# 10236  [doctor]: Good morning. How are you doing toda...   B3781
#
#                  ICD10_desc
# 0         PAIN IN LEFT KNEE
# 1         PAIN IN LEFT KNEE
# 2         PAIN IN LEFT KNEE
# 3         PAIN IN LEFT KNEE
# 4         PAIN IN LEFT KNEE
# ...                     ...
# 10232      NIPPLE DISCHARGE
# 10233  CANDIDAL ESOPHAGITIS
# 10234  CANDIDAL ESOPHAGITIS
# 10235  CANDIDAL ESOPHAGITIS
# 10236  CANDIDAL ESOPHAGITIS
#
# [10237 rows x 4 columns]

# %%
RANDOM_STATE = 666
VALIDATION_SIZE = 0.2

rng = np.random.default_rng(RANDOM_STATE)
indices = rng.permutation(len(data))

validation_len = int(len(data) * VALIDATION_SIZE)
validation_idx = indices[:validation_len]
train_idx = indices[validation_len:]

train = data.iloc[train_idx].reset_index(drop=True)
validation = data.iloc[validation_idx].reset_index(drop=True)

# %%
train.to_json("ft_train.json")
validation.to_json("ft_validation.json")
