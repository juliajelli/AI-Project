# %%
import json
import pandas as pd

# %%
from pathlib import Path

csv_folder = Path("csv")
csv_folder.mkdir(exist_ok=True)

# %%
training_data = pd.read_json("ft_train.json")
test_data = pd.read_json("ft_validation.json")

# %%
RANDOM_STATE = 666

training_data.to_csv("csv/training_data.csv", index=False)
test_data.to_csv("csv/test_data.csv", index=False)

activation_data = test_data.sample(n=1, random_state=RANDOM_STATE)
activation_data.to_csv("csv/activation_data.csv", index=False)
